# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
def click_event(event, x, y, flags, params):
    
    if event == cv2.EVENT_LBUTTONDOWN:
        pts.append((x,y))
        print(pts)

if __name__=="__main__":

    img1 = cv2.imread("pic1.jpg",1)
    img2 = cv2.imread('pic2.jpg', 1)# Select ROI


    r = cv2.selectROI(img1)


    # Crop image

    imCrop = img1[int(r[1]):int(r[1]+r[3]), int(r[0]):int(r[0]+r[2])]



    # Display cropped image

    cv2.imshow("Image", imCrop)
    cv2.imwrite("crop.jpg",imCrop)
#     print(cropped)
  
    #print(imCrop)

    cv2.waitKey(0)
    cv2.destroyAllWindows()

    plt.figure(figsize=[15,50])
    plt.subplot(121);plt.imshow(imCrop[:,:,::-1]);plt.title("Original Image");

# %%
cv2.setMouseCallback('imCrop', click_event)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-b0e449046e94> in <module>
# ----> 1 cv2.setMouseCallback('imCrop', click_event)
#
# error: OpenCV(4.5.3) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-u4kjpz2z\opencv\modules\highgui\src\window_w32.cpp:2559: error: (-27:Null pointer) NULL window: 'imCrop' in function 'cvSetMouseCallback'

# %%
def click_event(event, x, y, flags, params):
    
    if event == cv2.EVENT_LBUTTONDOWN:
        pts.append((x,y))
        print(pts)
 
        
 
        # displaying the coordinates
        # on the image window
#         font = cv2.FONT_HERSHEY_SIMPLEX
#         cv2.putText(img, str(x) + ',' +
#                     str(y), (x,y), font,
#                     1, (255, 0, 0), 2)
#         cv2.circle(copy,np.int32(pts), 5, (255,0,0), 1)
        cv2.imshow('image', img)
 
   
    

if __name__=="__main__":
    image = cv2.imread("crop.jpg",1)
    copy = image.copy()
    pts=[]
    img = cv2.imread('crop.jpg', 1)
 
    cv2.imshow('image', img)
 
    cv2.setMouseCallback('image', click_event)
    print(pts)
    cv2.waitKey(0)
 
    cv2.destroyAllWindows()
# Out:
# []

# %%
img2 = cv2.imread('pic2.jpg', 1)
pts=abs(np.float32(pts))


w,h,z=image.shape
r=(h,w)
img2 = cv2.resize(img2, r, interpolation = cv2.INTER_AREA)
x,y,z=img2.shape
pts2=[(0,0),(x,0),(0,y),(x,y)]
pts2=abs(np.float32(pts2))

# %%
M = cv2.getPerspectiveTransform(pts2,pts)
transformation = cv2.warpPerspective(img2,M,np.int32((x,y)))


print(pts)
print(pts2)
plt.figure(figsize=[15,50])
plt.subplot(121);plt.imshow(copy[:,:,::-1]);plt.title("Original Image");
plt.subplot(122);plt.imshow(transformation[:,:,::-1]);plt.title("Transformed Image");
